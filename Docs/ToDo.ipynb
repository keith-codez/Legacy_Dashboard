# %% [markdown]
# ### To Do List

# %% [markdown]
# - add confirm modal to all edit/update pages
# - add better ui for phone number form field to avoid confusion
# - add select from options for the industry field so as to avoid typing unless adding new industry
# - add modal / link to prefilled payment recording page from specific invoice and add "add payment" to 3 dots in invoices
# - add real login for manager
# - add owners dashboard
# - add real user who crated the interaction record not always admin
# - add permissions for owner to log in
# - deploying and dockerizing
# - ensure no re-allocation of unit while occupied
# - to add filter for invoices and payment setc to show balances/ paid or unpaid etc
# - fix alignment of table in reports page
